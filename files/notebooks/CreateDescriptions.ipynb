# %%
from openai import OpenAI
import os
from numpy import random
#Setze deine OpenAI API Schlüssel hier ein


client = OpenAI(api_key='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')

def generate_description_from_file(file_path, random):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
# Anpassen, falls du andere Einstellungen verwenden möchtest
    response = client.chat.completions.create(
        model="gpt-4-1106-preview",
        messages=[
        {
          "role": "system",
          "content": "Fasse abstrakt (ohne konkrete Beispiele) den Inhalt (content), den du bekommst, in GENAU ZWEI Sätzen zusammen.\
         Vermeide unnötig lange Formulierungen. Beginne, mit z.B. " + random
        },
        {
          "role": "user",
          "content": content
        }
      ],
      temperature=0.5,
      max_tokens=400,
      top_p=1,
    )
    

    # Extrahiere den generierten Text aus der API-Antwort
    description = response.choices[0].message.content
    return description

def main():
    # Passe den Pfad zum Verzeichnis mit deinen Textdateien an
    directory = 'C:/Users/Thomas/Downloads/transcripts'

    # Gehe durch jede Datei im Verzeichnis
    for filename in os.listdir(directory):
        if filename.endswith('.txt'):
            file_path = os.path.join(directory, filename)
            tetraederroll = random.random() * 10
            if(tetraederroll < 1):
                description = generate_description_from_file(file_path, "Innerhalb dieses Konzepts...")
            elif(tetraederroll < 2):
                description = generate_description_from_file(file_path, "Im Rahmen dieses Ansatzes...")
            elif(tetraederroll < 3):
                description = generate_description_from_file(file_path, "Im Rahmen dieses Konzepts...")
            elif(tetraederroll < 4):
                description = generate_description_from_file(file_path, "Im Rahmen des vorliegenden Konzepts...")
            elif(tetraederroll < 5):
                description = generate_description_from_file(file_path, "Der Ansatz...")
            elif(tetraederroll < 6):
                description = generate_description_from_file(file_path, "Bei diesem Ansatz...")
            elif(tetraederroll < 7):
                description = generate_description_from_file(file_path, "Die Konzeption...")
            elif(tetraederroll < 8):
                description = generate_description_from_file(file_path, "Die Idee...")
            elif(tetraederroll < 9):
                description = generate_description_from_file(file_path, "Der Begriff...")
            else:
                description = generate_description_from_file(file_path, "Hier werden...")
            print(f"Beschreibung für {filename}: {description}")

if __name__ == "__main__":
    main()
# Out:
# Beschreibung für Java_Anweisungen_Ausdruecke.txt: Im Rahmen des vorliegenden Konzepts werden Anweisungen definiert als Bestandteile eines Programms, die durch Strichpunkte oder andere Unterteilungen abgegrenzt sind und verschiedene Formen wie Ausdrücke oder Zuweisungen annehmen können. Ausdrücke wiederum sind spezifische Teile eines Programms, die Werte durch Operationen mit Konstanten oder Variablen berechnen, wobei die Ausführungsreihenfolge von links nach rechts erfolgt.
# Beschreibung für Java_Anweisungen_Block.txt: Der Begriff "Block" bezieht sich auf einen Codeabschnitt, dessen Variablen nur innerhalb dieses Abschnitts existieren und nach dessen Ende die Variablen nicht mehr verfügbar sind. Anweisungen innerhalb eines Blocks werden sequentiell ausgeführt, wobei jede Anweisung durch einen Strichpunkt getrennt ist, und obwohl ein Block selbst als eine Anweisung gilt, ist der abschließende Strichpunkt optional.
# ...

# %%
directory = 'C:/Users/Thomas/Downloads/transcripts'
for filename in os.listdir(directory):
        if filename.endswith('.txt'):
            #file_path = os.path.join(directory, filename)
            #description = generate_description_from_file(file_path)
            #print(f"Beschreibung für {filename}: {description}")
            if filename[:-4]:
                print("True")
            else:
                print("False")
# Out:
# True
# True
# True
# True
# True
# True
# True
# True

# %%
import csv
count = 0

with open('C:/Users/Thomas/Documents/links.CSV', newline='') as csvfile:

    spamreader = list(csv.reader(csvfile, delimiter=' ', quotechar='|'))

    
    directory = 'C:/Users/Thomas/Downloads/transcripts/transkripte'
    for row in spamreader:
        if filename.endswith('.txt'):
            found = False
            for filename in os.listdir(directory):
                #if ', '.join(row).split('/')[-1:][0].split('.')[0] == 'Java_Anwesungen_Ausdruecke' and filename[:-4] == 'Java_Anweisungen_Ausdruecke':
                    #print("Java_Anweisungen_Ausdruecke")
                
                if ', '.join(row).split('/')[-1:][0].split('.')[0] == filename[:-4]:
                    print(filename[:-4])
                    found = True
            if not found:
                if ', '.join(row).split('/')[0][0] == "V":
                    print("Tippfehler, manuell hinzufuegen")
                    count = count + 1
                else:
                    print("")
            #file_path = os.path.join(directory, filename)
            #description = generate_description_from_file(file_path)
            #print(f"Beschreibung für {filename}: {description}")
                #if ', '.join(row).split('/')[-1:][0].split('.')[0] == filename[:-4]:
print(count)
# Out:
# 0

# %%
"""
import csv
with open('C:/Users/Thomas/Documents/links.CSV', 'w', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    spamwriter = csv.writer(csvfile, delimiter=' ', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in spamreader:

        print(', '.join(row).split('/')[-1:][0].split('.')[0])
    
    #spamwriter.writerow(['Spam'] * 5 + ['Baked Beans'])
    #spamwriter.writerow(['Spam', 'Lovely Spam', 'Wonderful Spam'])
"""

# %%
from openai import OpenAI
import os
from numpy import random
#Setze deine OpenAI API Schlüssel hier ein


client = OpenAI(api_key='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')

def generate_description_from_file(file_path, NameDesKonzept):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
# Anpassen, falls du andere Einstellungen verwenden möchtest
    response = client.chat.completions.create(
        model="gpt-4-1106-preview",
        messages=[
        {
          "role": "system",
          "content": "Erstelle eine Zusammenfassung in zwei Sätzen zu dem Thema " + NameDesKonzept + ". Verwende hierzu das vorliegende Vorlösungstranskript."
        },
        {
          "role": "user",
          "content": content
        }
      ],
      temperature=0,
      max_tokens=400,
      top_p=1,
    )
    

    # Extrahiere den generierten Text aus der API-Antwort
    description = response.choices[0].message.content
    return description

def main():
    # Passe den Pfad zum Verzeichnis mit deinen Textdateien an
    directory = 'C:/Users/Thomas/Downloads/transcripts'

    # Gehe durch jede Datei im Verzeichnis
    import csv
    count = 0

    with open('C:/Users/Thomas/Documents/links.CSV', newline='') as csvfile:

        spamreader = list(csv.reader(csvfile, delimiter=' ', quotechar='|'))


        directory = 'C:/Users/Thomas/Downloads/transcripts/transkripte'
        for row in spamreader:
            #if filename.endswith('.txt'):
            found = False
            for filename in os.listdir(directory):
                    #if ', '.join(row).split('/')[-1:][0].split('.')[0] == 'Java_Anwesungen_Ausdruecke' and filename[:-4] == 'Java_Anweisungen_Ausdruecke':
                        #print("Java_Anweisungen_Ausdruecke")

                if ', '.join(row).split('/')[-1:][0].split('.')[0] == filename[:-4]:
                    file_path = os.path.join(directory, filename)
                    #description = generate_description_from_file(file_path,filename[:-4].replace("_"," "))
                    #print(filename[:-4].replace("_"," "))
                    found = True
            if not found:
                if ', '.join(row).split('/')[0][0] == "V":
                    #print(generate_description_from_file(file_path,filename[:-4].replace("_"," ")))
                    #print(generate_description_from_file(file_path,', '.join(row).split('/')[-1:][0].split('.')[0]))
                    print(', '.join(row).split('/')[-1:][0].split('.')[0])
                    count = count + 1
                #else:
                    #print("")

if __name__ == "__main__":
    main()
# Out:
# Python_mutable_immutable
# Python_FunktionaleProgrammierung_pureFunctions
# Python_FunktionaleProgrammierung_CodeBeispiel_Goofspiel
# Python_Rekursion_CodeBeispiel_Goofspiel
# Python_Tools_Map
# Python_Tools_Reduce
# Java_Anwesungen_Ausdruecke
# Java_Kontrollstukturen_if_else
