# %%
from openai import OpenAI
import os
import csv
import pandas as pd
import random

# Set your OpenAI API key here
client = OpenAI(api_key='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')

def generate_description_from_file(NameDesKonzept):
    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
        {
          "role": "system",
          "content": "Erstelle eine Zusammenfassung in zwei Sätzen zu dem Thema " + NameDesKonzept + " im Zusammenhang einer einführenden Informatikvorlesung zu Algorithmen und Datenstrukturen in C++. Erwähne diesen Zusammenhang nicht direkt, dies ist nur als Information für dich."
        }
      ],
      temperature=0,
      max_tokens=400,
      top_p=1,
    )
    
    description = response.choices[0].message.content
    return description

def main():
    # Path to your CSV file
    original_csv_path = 'C:/Users/Thomas/Documents/hefl/files/Kompetenzraster_AUD.csv'

    # Read the CSV file
    df = pd.read_csv(original_csv_path, sep=',', encoding='utf-8')

    # Iterate through each row in the DataFrame
    # Iterate through each row in the DataFrame
    for index, row in df.iterrows():
        topic = row['topic']
        
        # Generate description for the topic
        description = generate_description_from_file(topic)
        
        # Add the generated description to the 'description' column
        df.at[index, 'description'] = description

    # Save the updated DataFrame back to CSV
    df.to_csv(original_csv_path, sep=',', encoding='utf-8', index=False)

    print("Descriptions have been generated and added to the CSV file.")

if __name__ == "__main__":
    main()
