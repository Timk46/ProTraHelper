# %%
from llama_index.llms import Ollama
from llama_index.llms import ChatMessage

from llama_index import SimpleDirectoryReader, StorageContext
from llama_index.indices.vector_store import VectorStoreIndex
from llama_index.vector_stores import PGVectorStore
import textwrap
import openai
import psycopg2

from langchain.embeddings.openai import OpenAIEmbeddings

import os

os.environ["OPENAI_API_KEY"]="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"

# %%
llm = Ollama(
    model="em_german_leo_mistral.Q5_K_M:latest",
    base_url="http://webui.bshefl0.bs.informatik.uni-siegen.de/ollama",
    temperature= 0
    )

# %% [markdown]
# Test Basic Outpt of German Ollama Model

# %%
messages = [
    ChatMessage(
        role="system", content="Du bist ein hilfreicher Assistent."
    ),
    ChatMessage(role="user", content="Erkläre Rerkusion in drei Sätzen."),
]
resp = llm.stream_chat(messages)

for r in resp:
    print(r.delta, end="")
# Out:
#  Die Methode der Rekursion ist eine Technik, die in verschiedenen Programmiersprachen verwendet wird, um wiederkehrende Probleme aufzulösen. Sie funktioniert durch das Aufteilen eines größeren Problems in kleinere Teile und deren Verwendung zur Lösung des ursprünglichen Problems. Der Algorithmus ist selbst-aufrufend, was bedeutet, dass er sich selbst aufruft, um den Rest des Problems zu lösen.

# %% [markdown]
# Connect to pgVector DB / Store

# %%
vector_store = PGVectorStore.from_params(
    database="vectordb",
    host="vectordb.bshefl0.bs.informatik.uni-siegen.de",
    password="qzx5vQG9WQ2b35eZUWujPUhVb8xRr",
    port=3306,
    user="root",
    table_name = "langchain_pg_embedding",
   # collection_name="OFP_512_64",
    embed_dim=1536,  # openai embedding dimension
    debug = True
)
index = VectorStoreIndex.from_vector_store(vector_store=vector_store)
query_engine = index.as_query_engine()
response = query_engine.query("Rerkusion")
print(textwrap.fill(str(response), 100))
# Out:
# 2023-12-09 15:26:02,448 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2023-12-09 15:26:02,449 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-12-09 15:26:02,506 INFO sqlalchemy.engine.Engine select current_schema()
# 2023-12-09 15:26:02,507 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-12-09 15:26:02,562 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2023-12-09 15:26:02,563 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-12-09 15:26:02,618 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-12-09 15:26:02,620 INFO sqlalchemy.engine.Engine CREATE EXTENSION IF NOT EXISTS vector
# 2023-12-09 15:26:02,620 INFO sqlalchemy.engine.Engine [generated in 0.00093s] {}
# 2023-12-09 15:26:02,677 INFO sqlalchemy.engine.Engine COMMIT
# 2023-12-09 15:26:02,705 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-12-09 15:26:02,705 INFO sqlalchemy.engine.Engine CREATE SCHEMA IF NOT EXISTS public
# ...
